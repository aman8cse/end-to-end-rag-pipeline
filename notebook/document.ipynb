# %% [markdown]
# ### Data Injestion

# %%
### Document Structure

from langchain_core.documents import Document

# %%
document = Document (
    page_content = "this is a sample text content, will be used to generate responses",
    metadata = {
        "source": "example.txt",
        "pages": 1,
        "author": "Aman Agrahari",
        "date_Created": "27/05/2026"
    }
)
document
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Aman Agrahari', 'date_Created': '27/05/2026'}, page_content='this is a sample text content, will be used to generate responses')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
Easy to learn and use
Extensive standard library
Cross-platform compatibility
Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.
"""
}

for filepath, content in sample_texts.items():
    with open(filepath, 'w', encoding="utf-8") as f:
        f.write(content)
print("Sample texts file is created 💲")
# Out:
# Sample texts file is created 💲

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")

document = loader.load()

print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\nEasy to learn and use\nExtensive standard library\nCross-platform compatibility\nStrong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.\n')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
"../data/text_files",
glob=" **/*. txt", ## Pattern to match files
loader_cls= TextLoader, ##loader class to use
loader_kwargs={'encoding': 'utf-8'},
show_progress=True
)

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader, DirectoryLoader

### load all the next files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls= PyMuPDFLoader,
    show_progress=False
)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2026-03-30T09:24:36+00:00', 'source': '..\\data\\pdf\\Aman Agrahari FS4S.pdf', 'file_path': '..\\data\\pdf\\Aman Agrahari FS4S.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': 'resume template.pdf', 'author': 'Aman', 'subject': '', 'keywords': 'DAHELWz6xSo,BAGZGbj1AHg,0', 'moddate': '2026-03-30T09:24:36+00:00', 'trapped': '', 'modDate': "D:20260330092436+00'00'", 'creationDate': "D:20260330092436+00'00'", 'page': 0}, page_content='Aman Agrahari\n7234909407\nGITHUB\n|\n|\nEDUCATION\nEXPERIENCE\nSmart India Hackathon\nTeam Leader\nSept 2024 - Aug 2028\nApril 2025 - Present\nSept 2025 - Nov 2025\naman8cse@gmail.com |\nPRODUCTS & PROJECTS\nRenaissance’26 - Production-Grade E-Summit Management Platform\nLIC Calc - Insurance Analytics & Advisory Engine\nArchitected and deployed a full-stack event management system to serve 2,500+ registered users.\nSecure role based admin, volunteer and user control panel for managing events & registrations.\nGamified participation using coins and payment gateway\nImpact - Due to online platform we reduced manual admin jobs by 80% and increased participation in events by 40%\nA platform for LIC agents to manage the client data online and export customized PDF reports for insurance plans\nUses Gemini to filter chatbot based input of data fields and built-in engine for policy calculation.\nImpact - PDF customized plans increased client approval rates by 50%\nCrew Or Crook - Real-Time Multiplayer Gaming Platform (AmongUs Inspired)\nDesigned a real-time multiplayer game backend supporting 2000+ users built on NodeJS.\nBuilt WebSocket-based live synchronization engine for player states and game-room logic.\nUses Redis for blazing-fast data exchanges and optimizes database query times.\nEngineered dynamic room management and session handling for concurrent gameplay using MongoDB.\nMy Attendance - Live QR-Based Smart Attendance Platform\nDeveloped a dynamic QR based system to manage attendance 100% online and remotely.\nProvides statistical analysis with Admin & User dashboards increasing transparency for both parties.\nOffers proxy-less attendance without any expensive hardware.\nImpact - Reduced attendance time by 8 minutes and manual errors to 0%, resolved proxy attendance due to QR + Geotag.\nQR JS\nMERN|\nTailwind CSS\nPDF JS\nGemini 1.5 Flash\n|\n|\nMERN|\nRazorpay\nMERN|\nExpress JS\n|\nNODE|\n| Redis\nJSS Noida\nB.Tech - CSE (DATA SCIENCE)\nCGPA: 8.05\nRanked 1 out of 130 teams in SIH internal round\nLead a team of 6 members, worked of 2 different projects, developed MVP using MERN and blockchain.\nContributed in App development and team leadership\nGoogle Developers Group JSS \nWeb Developer\nLearned to work in a professional environment following code writing and reviewing guidelines\nWorked for 4 months on a recent project and gained experience with real world git - github usage in teams\nDeployed backend systems on AWS, Render, Vercel and similar platforms\nFull-stack developer experienced in building modular, scalable web apps. Developed and deployed production systems\nserving 4,000+ users, with strong focus on backend architecture, performance optimization, and clean system design.\nSKILLS\nFrontend Development :  ReactJS, Redux, CSS3, Tailwind CSS, GSAP, Lenis\nBackend Development :  NodeJS, Express, MongoDB, Redis\nLanguages: Java (Solved 200+ Leetcode Problems), JavaScript, C, Python\nTools : GitHub, AWS, Vercel, Render, Figma, Canva \nLINKEDIN\n|\nPORTFOLIO')]
